# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepanshuThakur06/Play-store-data-analysis/blob/Deep/Play_store_review_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Play store data analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual (Deepanshu)

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# 📱 The Play Store app analysis project was a deep dive into understanding app performance and user behavior. It involved collecting and cleaning diverse app data, followed by in-depth exploratory analysis and visualizations.
#
# 🔍 The project aimed to uncover insights into app categories, ratings, user sentiments, and engagement metrics. Through data wrangling and exploratory analysis, it revealed patterns in popular app genres, user satisfaction levels, and relationships between downloads and reviews.
#
# 🌟 Key findings included identifying popular app categories, understanding user sentiments from reviews, and discovering correlations between app features and user engagement.
#
# 🚀 The analysis provides actionable insights for developers, marketers, and stakeholders, aiding informed decision-making for app optimization and strategic planning.
#
# 💡 Ultimately, this data-driven approach illuminated trends and user preferences within the Play Store app ecosystem, offering valuable insights for app improvement and market strategies.![image_processing20200506-1844-15ntpsj.gif](data:image/gif;base64,...)

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# 📊 The main aim of this project is to delve into Play Store data and user reviews, extracting valuable insights about app performance, user sentiments, and the factors that drive app success. This involves exploring connections between various app features—like ratings and installs—conducting a thorough sentiment analysis on user reviews, and uncovering patterns within diverse app categories. Ultimately, the goal is to optimize app performance and enhance user satisfaction by

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# **Optimize App Performance:** Utilize insights to enhance app quality, functionality, and performance metrics like ratings and installs.
#
# **Enhance User Satisfaction:** Analyze user sentiments to identify areas for improvement and increase overall user satisfaction and engagement.
#
# **Data-Driven Decision-making:** Use insights to make informed decisions for app development, marketing, and feature enhancements across different app categories.
#
# **Maximize Reach and Engagement:** Tailor strategies to increase app installs, improve user retention, and attract a broader audience based on user preferences and market trends.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df1=pd.read_csv('/content/drive/MyDrive/playstore_data/Play Store Data.csv') #df1=playstore data csv
df2=pd.read_csv('/content/drive/MyDrive/playstore_data/User Reviews.csv')  #df2=users review csv

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Dataset First View

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Dataset First Look
df1

# %%
df2

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print("For dataset 1(Rows,columns):-",df1.shape)
print("For dataset 2(Rows,columns):-",df2.shape)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df1.info()

# %%
df2.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
print(df1.duplicated().sum())
print(df2.duplicated().sum())

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print("For playstore app Data")
print(df1.isnull().sum())
print("For User review data :-")
print(df2.isnull().sum())

# %%
#Fill missing value in df2
df2['Translated_Review'].fillna('Translation not available', inplace=True)
df2['Sentiment'].fillna('Unknown Sentiment', inplace=True)
df2['Sentiment_Polarity'].fillna(0, inplace=True)
df2['Sentiment_Subjectivity'].fillna(0, inplace=True)

# %%
rating_mean = df1['Rating'].mean()
df1['Rating'].fillna(rating_mean, inplace=True)
# Filling missing values in 'Type' and 'Content Rating' with the mode
type_mode = df1['Type'].mode()[0]
df1['Type'].fillna(type_mode, inplace=True)

content_rating_mode = df1['Content Rating'].mode()[0]
df1['Content Rating'].fillna(content_rating_mode, inplace=True)
# Filling missing values in 'Current Ver' and 'Android Ver' with the most common value
current_ver_mode = df1['Current Ver'].mode()[0]
df1['Current Ver'].fillna(current_ver_mode, inplace=True)

android_ver_mode = df1['Android Ver'].mode()[0]
df1['Android Ver'].fillna(android_ver_mode, inplace=True)

# %%
# Visualizing the missing values

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
print(df1.columns)
print(df2.columns)

# %%
# Dataset Describe
print(df1.describe())

print(df2.describe())

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **For Play Store App Data (like df1):**
#
# * **App:** Name of the application.
# * **Category:** Category under which the app falls (e.g., productivity, games, social).
# * **Rating:** User ratings of the app (typically on a scale of 1 to 5).
# * **Reviews:** Number of user reviews for the app.
# * **Size:** Size of the app.
# * **Installs:** Number of times the app has been installed.
# * **Type:** Whether the app is free or paid.
# * **Price:** Price of the app (if it's a paid app).
# * **Content Rating:** Rating based on the app's content (e.g., Everyone, Teen, Mature).
# * **Genres:** Genre(s) the app belongs to.
# * **Last Updated:** Date when the app was last updated.
# * **Current Ver:** Current version of the app.
# * **Android Ver:** Minimum required Android version to run the app.
#
# **For User Review Data (like df2):**
#
# * **App:** Name of the application.
# * **Translated_Review:** User review translated into a specified language.
# * **Sentiment:** Sentiment derived from the user review (e.g., positive, negative, neutral).
# * **Sentiment_Polarity:** Numeric measure indicating the sentiment intensity (-1 to 1).
# * **Sentiment_Subjectivity:** Numeric measure indicating the sentiment subjectivity (0 to 1).

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for column in df1.columns:
    unique_values = df1[column].unique()
    print(f"Unique values for '{column}':\n{unique_values}\n")

# %%
for column in df2.columns:
    unique_values = df2[column].unique()
    print(f"Unique values for '{column}':\n{unique_values}\n")

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Extracting unique values from the 'Category' column in df1
unique_categories = df1['Rating'].unique()
print(unique_categories)

# %%
# Filter apps with a rating greater than 4.5
high_rated_apps = df1[df1['Rating'] > 4.5]
Low_rated_apps=df1[df1['Rating']<3.0]

# %%
high_rated_apps

# %%
Low_rated_apps

# %%
# Filter apps in the 'Games' category
games_category = df1[df1['Category'] == 'GAME']

# %%
games_category

# %%
# Merge df1 and df2 on the 'App' column
merged_data = pd.merge(df1, df2, on='App')
merged_data

# %%
#Group by 'Category' and Calculate Average 'Rating':
avg_rating_per_category = merged_data.groupby('Category')['Rating'].mean().reset_index()
avg_rating_per_category

# %%
merged_data['Last Updated'] = pd.to_datetime(merged_data['Last Updated'])
merged_data['Year_Last_Updated'] = merged_data['Last Updated'].dt.year

# %%
# Creating a binary column indicating whether the app has high reviews (more than 10000)
merged_data['High_Reviews'] = merged_data['Reviews'].apply(lambda x: "Better" if x > 10000 else "not so good")

# %%
# Remove duplicate based on some columns
merged_data.drop_duplicates(subset=['App','Translated_Review','Reviews','Rating','Sentiment'],inplace=True)

# %%
merged_data.shape

# %%
free_apps=merged_data[merged_data['Type']=='Free']

# Group by 'Category' for free apps and calculate the count of apps in each category
free_apps_by_category = free_apps.groupby('Category').size().reset_index(name='App_Count')

# %%
paid_apps=merged_data[merged_data['Type']=='Paid']
paid_app_by_category=paid_apps.groupby('Category').size().reset_index(name='App_count')

# %%
free_apps_by_category

# %%
paid_app_by_category

# %%
merged_data.columns

# %%
# Remove commas and plus signs from the 'Installs' column
merged_data['Installs'] = merged_data['Installs'].str.replace(',', '').str.replace('+', '')

# Convert the 'Installs' column to integer type
merged_data['Installs'] = merged_data['Installs'].astype(int)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **Data Manipulations:**
#
# **Subset Creation:**
# * paid_apps: Filtered apps where 'Type' is 'Paid'.
# * free_apps: Filtered apps where 'Type' is 'Free'.
# * games_category: Filtered apps in the 'Games' category.
# * Low_rated_apps: Subset of apps with low ratings (threshold not specified).
# * high_rated_apps: Subset of apps with high ratings (threshold not specified).
#
# **Aggregations:**
# * avg_rating_per_category: Calculated average ratings per category.
# * free_apps_by_category: Counted free apps per category using a groupby operation.
# * paid_apps_by_category: (Assumption based on the provided columns) Possibly a count of paid apps per category, but not explicitly mentioned.
#
# **Insights or Findings:**
#
# * Category-wise Analysis: Exploration based on app categories, such as average ratings per category and counts of free/paid apps in each category.
# * App Type Comparison: Comparison between free and paid apps, possibly analyzing differences in ratings, reviews, or other factors.
# * Games Category Analysis: Specific focus on apps categorized under 'Games'.
# * Rating Segmentation: Separation of apps into low-rated and high-rated groups (based on unspecified thresholds).

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### **Question 1: How do the number of installs vary across different app types and categories?**

# %%
# Aggregate data: Count installs per app type and category
installs_grouped = merged_data.groupby(['Category', 'Type'])['Installs'].sum().reset_index()

pivot_installs = installs_grouped.pivot(index='Category', columns='Type', values='Installs')

pivot_installs.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title('Number of Installs by App Type and Category')
plt.xlabel('App Category')
plt.ylabel('Number of Installs')
plt.legend(title='App Type')
plt.xticks(rotation=50)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chosen chart, a stacked bar chart depicting the number of installs by app type and category, is ideal for showcasing the distribution of installs across categories while emphasizing the contribution of each app type within these categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Category-wise Installations:** The chart visually represents the total installs for each app category, further segmented by app type (Free or Paid). It illustrates which categories attract higher installs and the contribution of each app type to these installations.
# * **Comparative Analysis:** By comparing the total installs within each category, it becomes evident which categories garner the most user interest and whether there's a significant difference in installation counts between free and paid apps within these categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# Insights indicating higher installations in specific categories or greater traction for a particular app type within a category can guide business decisions. They offer direction for resource allocation, marketing strategies, or potential revenue generation avenues.
#
# **Negative Growth Potential Insights:**
#
# If certain categories show notably lower total installs or minimal variation between free and paid app installations, it might indicate a lack of user interest or competitive challenges within those categories. This insight can guide strategies to revamp offerings or reconsider investments in those categories.

# %% [markdown]
# #### **Question 2: How does the price of apps relate to their ratings?**

# %%
sns.set(style="whitegrid")

# Scatter plot for Price vs. Rating using Seaborn
plt.figure(figsize=(8, 6))
sns.scatterplot(data=merged_data, x='Price', y='Rating', alpha=0.5)
plt.title('App Ratings vs. Prices')
plt.xlabel('Price')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chosen scatter plot, comparing app ratings against their respective prices, is selected for its effectiveness in showcasing the potential relationship or lack thereof between these two continuous variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Price-Rating Relationship:** The scatter plot offers a visual representation of the relationship, or lack thereof, between app prices and their corresponding ratings. It helps identify any potential trends or patterns between these variables.
#
# **Concentration of Data Points:** The concentration of data points within certain price ranges with varying ratings indicates where most apps lie in terms of pricing and how their ratings distribute within these price segments.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# Identifying a positive correlation between higher-priced apps and higher ratings might indicate a market segment willing to pay more for better-quality apps. This insight can guide pricing strategies for premium offerings.
# Discovering clusters of highly-rated apps within specific price ranges could help in optimizing pricing strategies to maximize profitability while maintaining user satisfaction.
#
# **Negative Growth Potential Insights:**
#
# Lack of correlation or scattered data points across all price ranges might imply that price isn't a dominant factor influencing app ratings. In such cases, solely adjusting prices may not significantly impact ratings or user satisfaction, requiring a focus on other aspects like features or usability.
# An overwhelming concentration of lower-rated apps across all price ranges might indicate an issue with app quality or functionality. This insight suggests a need for quality improvements rather than price adjustments.

# %% [markdown]
# #### **Question 3: How are ratings distributed across different app categories?**

# %%
sns.set(style="whitegrid")

# Create a box plot using Seaborn
plt.figure(figsize=(12, 8))
sns.boxplot(x='Category', y='Rating', data=merged_data, palette='Set3')
plt.title('Rating Distribution across App Categories')
plt.xlabel('App Category')
plt.ylabel('Rating')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The selected box plot showcasing the distribution of app ratings across different categories is specifically chosen for its ability to illustrate the variation and central tendency of ratings within each category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. **Category Rating Distribution:** The plot helps visualize the spread of ratings across different categories, showcasing where most ratings fall within each category and whether outliers exist.
# 2. **Comparative Analysis:** Comparing box plots of various categories reveals disparities in rating distributions, highlighting categories with higher median ratings or those with wider variability.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# * Categories with consistently higher ratings might indicate areas of strength or user satisfaction, guiding further investment or development in those categories.
# * Understanding categories with broader rating ranges or outliers can inform strategies to address quality issues or enhance user experience.
#
# **Negative Growth Potential Insights:**
#
# * Categories with consistently lower median ratings or more widespread variability might imply lower user satisfaction or quality concerns. It could necessitate quality improvements or strategic adjustments within those categories to prevent negative impact on growth

# %% [markdown]
# #### **Question 4: Are there any trends between sentiments derived from user reviews and app ratings?**

# %%
sentiment_ratings = merged_data.groupby('Rating')[['Sentiment_Polarity', 'Sentiment_Subjectivity']].mean().reset_index()

# Melt the DataFrame to prepare for visualization
sentiment_ratings_melted = sentiment_ratings.melt('Rating', var_name='Sentiment', value_name='Value')

# Line plot using Seaborn
plt.figure(figsize=(10, 6))
sns.lineplot(x='Rating', y='Value', hue='Sentiment', data=sentiment_ratings_melted, marker='o')
plt.title('Sentiment Analysis vs. Ratings')
plt.xlabel('Rating')
plt.ylabel('Sentiment Value')
plt.legend(title='Sentiment')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Visualizing Sentiment Trends: The line plot effectively illustrates how sentiment polarity and subjectivity vary concerning different app ratings, enabling the identification of potential trends or patterns.
# Rating-Sentiment Correlation: This plot helps discern any potential correlations or trends between user ratings and sentiment analysis, providing insights into sentiment changes concerning rating variations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Sentiment Variation with Ratings:** The plot visually depicts how sentiment polarity and subjectivity change across different app ratings.
# * **Correlation Exploration:** Observing trends or patterns might suggest whether certain ratings consistently correspond to particular sentiment measures.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# * Identifying a consistent positive or negative sentiment trend with specific ratings could help understand user perceptions, guiding app improvements or feature enhancements.
# * Insights into sentiment changes across different ratings might aid in developing strategies to enhance user experience or address concerns.
#
# **Negative Growth Potential Insights:**
#
# * Lack of discernible trends or erratic fluctuations in sentiment measures across ratings may indicate inconsistencies in user perceptions or data quality issues. This might require further analysis or improvement in sentiment analysis techniques to derive actionable insights.

# %% [markdown]
# #### **Question 5: How do the ratings differ between free and paid apps?**

# %%
# Aggregate data for average ratings based on app type
avg_ratings_by_type = merged_data.groupby('Type')['Rating'].mean().reset_index()

# Create side-by-side bar plot using Seaborn
plt.figure(figsize=(8, 6))
sns.barplot(x='Type', y='Rating', data=avg_ratings_by_type, palette='coolwarm')
plt.title('Average Ratings of Free vs. Paid Apps')
plt.xlabel('App Type')
plt.ylabel('Average Rating')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * **Comparison of Averages:** Side-by-side bar plots effectively compare the average ratings of two different categories (here, free and paid apps) in a visually clear manner.
# * **Visual Emphasis:** The plot makes it easy to compare the central tendency (average ratings) between the two categories while highlighting potential differences or similarities.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Average Rating Comparison:** The plot illustrates the average ratings of free and paid apps, allowing for a direct comparison of their performance.
# * **Category Performance:** Identifying whether free or paid apps have higher average ratings provides insights into user perceptions of both app types.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# * Clear differences between average ratings may indicate user preferences or perceived value between free and paid apps, guiding strategies to enhance user satisfaction or monetization.
# * Understanding which category performs better in terms of ratings can influence resource allocation or feature prioritization.
#
# **Negative Growth Potential Insights:**
#
# * Lack of substantial differences in average ratings between free and paid apps might suggest challenges in differentiating or justifying the value proposition between the two categories.
# * Significantly lower ratings for either free or paid apps might indicate quality concerns that need to be addressed for better user satisfaction.

# %% [markdown]
# ####**Question 6: Are there outliers or extreme values in ratings or reviews?**

# %%
sns.set(style="whitegrid")

# Create a box plot to highlight outliers in ratings or reviews
plt.figure(figsize=(8, 6))
sns.boxplot(x='Rating', data=merged_data, flierprops=dict(marker='o', markersize=8, markerfacecolor='red', linestyle='none'))
plt.title('Box Plot of Ratings with Outliers Highlighted')
plt.xlabel('Ratings')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * **Outlier Identification:** Box plots effectively display the distribution of numerical data, allowing quick identification of outliers.
# * **Highlighting Outliers:** The plot enhances outlier visibility by marking them distinctly in red, aiding in their quick identification within the ratings data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Rating Distribution:** The plot showcases the distribution of ratings and identifies potential outliers that fall significantly outside the typical range of ratings.
#
# **Outlier Identification:** The red dots represent individual data points considered outliers based on the plot's criteria.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# * Identification of outliers in ratings might highlight specific apps that stand out due to extremely high or low ratings, prompting further investigation into their performance or user feedback.
# * Understanding outliers can guide decisions on app quality improvements or identifying successful strategies for high-rated apps.
#
# **Negative Growth Potential Insights:**
#
# * Presence of numerous outliers might indicate inconsistency in user satisfaction or data quality issues, potentially impacting user trust or app quality perception.

# %% [markdown]
# #### **Question 7: How has the number of app installs or updates changed over time?**

# %%
# Aggregating data for installs over different years
install_trend = merged_data.groupby('Last Updated')['Installs'].sum().reset_index()

# Plotting the line chart
plt.figure(figsize=(10, 6))
sns.lineplot(x='Last Updated', y='Installs', data=install_trend)
plt.title('Trend of Installs Over Different Years')
plt.xlabel('Year')
plt.ylabel('Installs')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Representation of Installs Over Dates:** The line chart was chosen to represent the trend of installs over various dates, possibly aiming to observe trends or patterns in app installs concerning the 'Last Updated' dates.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Installs over Dates:** The chart showcases how the number of installs fluctuates over different dates when apps were last updated.
#
# **Possible Seasonal Trends:** Any recurring patterns or spikes in installs over specific periods might be observed, indicating potential seasonal trends.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * ***Limited Insights for Yearly Trends:*** The granularity of date data might hinder precise insights into yearly trends, impacting the ability to make yearly-based strategic decisions.
# * **Difficulty in Actionable Insights:** Yearly insights are vital for long-term planning, and trends at a daily granularity might not provide actionable insights for strategic business decisions unless aggregated appropriately.
#
# **Negative Growth Potential Insights:**
#
# * **Lack of Yearly Perspective:** Focusing on daily trends might lead to overlooking macro-level trends or anomalies that might be evident only at a yearly level, potentially hindering long-term business planning.
# * **Misinterpretation of Short-Term Fluctuations:** Daily fluctuations might lead to misinterpretations or overemphasis on short-term trends that may not hold significance at a yearly level.

# %% [markdown]
# #### Question 8: Which genres have the highest average ratings, and how does popularity vary among them?

# %%
# Aggregate data for average ratings per genre
avg_ratings_per_genre = merged_data.groupby('Genres')['Rating'].mean().reset_index()

# Assuming 'Installs' represents popularity metrics
# Aggregate data for popularity (Installs) per genre
avg_installs_per_genre = merged_data.groupby('Genres')['Installs'].mean().reset_index()

# Merging both dataframes on 'Genres' to create a combined dataset
combined_data = pd.merge(avg_ratings_per_genre, avg_installs_per_genre, on='Genres')

# Plotting the grouped bar chart
plt.figure(figsize=(12, 8))

# Plotting average ratings
sns.barplot(x='Genres', y='Rating', data=combined_data, color='skyblue', label='Average Ratings')

# Plotting popularity (Installs)
sns.barplot(x='Genres', y='Installs', data=combined_data, color='salmon', label='Popularity (Installs)')

plt.title('Average Ratings per Genre and Popularity Comparison')
plt.xlabel('Genres')
plt.ylabel('Values')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Comparison of Multiple Metrics:** Grouped bar charts effectively compare two different metrics (average ratings and popularity) within the same visualization for different genres.
#
# **Visualizing Multiple Metrics:** The chart visualizes and compares two numerical metrics across categories (genres) using bars side by side.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Average Ratings Comparison:** The blue bars represent average ratings for each genre, allowing comparison of how different genres fare in terms of ratings.
#
# **Popularity Comparison:** The red bars (or the height of the bars) represent the popularity metric (assumed as installs), offering a comparison of popularity across genres.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Growth Potential Insights:**
# * **Genre Performance Comparison:** The comparison helps identify genres that perform well in terms of ratings and popularity, aiding decisions related to content creation, marketing, or resource allocation.
# * **Understanding User Preferences:** Insights into user preferences across genres guide strategies for content development or marketing tailored to popular genres.
#
# **Negative Growth Potential Insights:**
#
# * **Discrepancies Between Ratings and Popularity:** Significant differences between high-rated genres and their popularity might indicate discrepancies in user preferences or challenges in converting high ratings to high installs.
# * **Unpopularity of High-Rated Genres:** High ratings in genres with low popularity might indicate an issue in reaching the target audience or marketing strategies that need refinement.

# %% [markdown]
# #### **Question 9: Do users prefer smaller or larger apps? How does app size relate to ratings?**

# %%
merged_data['Size'] = merged_data['Size'].replace('Varies with device', np.nan)

# Convert 'Size' column to numerical values (remove 'M' or 'k' suffixes)
merged_data['Size'] = merged_data['Size'].str.replace('M', 'e6').str.replace('k', 'e3').astype(float)

# Plotting the scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Size', y='Rating', data=merged_data, alpha=0.6)
plt.title('App Size vs. Ratings')
plt.xlabel('App Size')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Visualizing Relationships:** Scatter plots are ideal for displaying relationships between two continuous variables, in this case, app size and ratings.
#
# **Understanding Patterns:** The plot helps identify any trends or patterns in how app size relates to app ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Size-Rating Relationship:** The plot showcases whether there's a discernible relationship or trend between app size and ratings.
#
# **Data Distribution:** The distribution of data points helps understand how ratings are distributed across different app sizes.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# * Identification of a positive correlation between larger app sizes and higher ratings might suggest that users perceive larger-sized apps as feature-rich or of higher quality.
# * Insights into any trends can guide decisions regarding app optimization, considering the impact of app size on user ratings.
#
# **Negative Growth Potential Insights:**
#
# * Lack of a clear trend or scattered data points might indicate that app size doesn't strongly correlate with ratings, suggesting other factors significantly influence user perceptions.

# %% [markdown]
# #### **Question 10: Is there any relationship between the time since the last update and the app's ratings or reviews?**

# %%
merged_data['Last Updated'] = pd.to_datetime(merged_data['Last Updated'])

# Extracting the year from the 'Last Updated' column
merged_data['Year_Last_Updated'] = merged_data['Last Updated'].dt.year

# Calculating yearly averages of ratings
yearly_avg_rating = merged_data.groupby('Year_Last_Updated')['Rating'].mean().reset_index()

# Plotting the line chart
plt.figure(figsize=(10, 6))
sns.lineplot(x='Year_Last_Updated', y='Rating', data=yearly_avg_rating, marker='o')
plt.title('Yearly Average Ratings')
plt.xlabel('Year')
plt.ylabel('Average Rating')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### **Question 11: What is the distribution of apps across different genres, and which genres dominate the market share?**

# %%
genre_counts = merged_data['Genres'].value_counts(normalize=True) * 100

# Filtering to show top 10 genres for better visualization
top_genres = genre_counts.head(10)

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_genres, labels=top_genres.index, autopct='%1.1f%%', startangle=140)
plt.title('Percentage Distribution of Apps across Genres')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Displaying Proportions:** Pie charts effectively illustrate proportions or percentages of categories (in this case, app genres) relative to the whole dataset.
#
# **Highlighting Top Categories:** It focuses on the top 10 genres to provide a clearer visualization of the most prevalent genres among apps..

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Genre Popularity:** The chart visually represents the percentage contribution of each top genre to the total number of apps, emphasizing the most prevalent genres.
# * **Relative Size Comparison:** Comparing the sizes of pie slices helps identify which genres dominate the app market among the top 10.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# * Identification of dominant genres helps in understanding market preferences, guiding decisions related to app development, marketing strategies, or content creation tailored to popular genres.
# * Insights into popular genres aid in targeting specific user segments or
# focusing resources on high-demand genres for better market penetration.
#
# **Negative Growth Potential Insights:**
#
# * Over-reliance on a few dominant genres might limit diversification or overlook potential opportunities in less prevalent genres.
# * Lack of diversity in top genres might indicate a narrow market focus, potentially limiting the audience reach or competitive edge.

# %% [markdown]
# #### **Question 12: What is the proportion of free versus paid apps in different categories?**

# %%
# Aggregate data for count of free and paid apps per category
apps_count_by_type = merged_data.groupby(['Category', 'Type']).size().unstack().fillna(0)

# Plotting the stacked bar chart
plt.figure(figsize=(12, 8))
apps_count_by_type.plot(kind='bar', stacked=True, cmap='coolwarm')
plt.title('Count of Free and Paid Apps per Category')
plt.xlabel('App Category')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.legend(title='App Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * **Comparison Across Categories:** Stacked bar charts effectively compare counts of different categories while breaking them down into sub-categories (here, free and paid apps).
# * **Visualizing Multiple Variables:** This chart type allows for a clear visual comparison of counts across categories while showing the contribution of each app type within those categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Category-wise App Distribution:** The chart showcases the total count of free and paid apps within each category, highlighting categories with more apps and the distribution between free and paid types.
# * **Relative Proportions:** The length of each stacked segment illustrates the proportion of free and paid apps within each category, aiding in understanding the dominance of one type over the other within specific categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# * Identification of categories with a substantial count of both free and paid apps indicates market diversity and potential opportunities for revenue generation from paid apps in those categories.
# * Understanding the distribution across categories guides strategies for resource allocation or feature development in specific categories.
#
# **Negative Growth Potential Insights:**
#
# * Categories dominated by free apps might pose challenges for revenue generation unless there's a strategy to monetize these categories through alternative means like ads or in-app purchases.
# * A skewed distribution towards one type in most categories might limit monetization potential or signify a lack of premium offerings within those categories.

# %% [markdown]
# #### **Question 13: Is there a correlation between the number of reviews and the app's rating?**

# %%
plt.figure(figsize=(8, 6))
plt.scatter(merged_data['Reviews'], merged_data['Rating'], alpha=0.5, color='blue')
plt.title('Relationship between Number of Reviews and App Ratings')
plt.xlabel('Number of Reviews')
plt.ylabel('App Rating')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * **Visualizing Relationships:** Scatter plots effectively show the relationship between two continuous variables, such as reviews and ratings, enabling observation of potential patterns or trends.
# * **Identifying Patterns:** Scatterplots aid in quickly identifying whether there's any discernible relationship or trend between the variables plotted.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Review-Rating Relationship:** The plot showcases how app ratings correlate with the number of reviews. It helps understand if there's any trend where higher reviews correspond to higher ratings or vice versa.
# * **Data Concentration:** The concentration of data points around certain values provides insight into where most apps lie in terms of ratings and the volume of reviews they receive.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# * A positive correlation between higher reviews and higher ratings might indicate that well-reviewed apps tend to have higher ratings, suggesting a connection between app quality and user satisfaction.
# * Understanding any trend or pattern can guide strategies to encourage user reviews, improve app quality, or prioritize features that positively impact user ratings.
#
# **Negative Growth Potential Insights:**
#
# * Lack of a clear trend or scattered data points might suggest that the number of reviews doesn't strongly correlate with app ratings, indicating other factors influencing user ratings.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
numerical_data = merged_data.select_dtypes(include=['float64', 'int64'])

# Compute the correlation matrix
correlation_matrix = numerical_data.corr()

# Plotting the correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap of Numerical Columns')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * **Visualizing Correlation Strength:** Heatmaps represent correlation coefficients between numerical attributes, offering a quick visual understanding of the strength and direction of relationships.
# * **Identification of High Correlations:** It helps in identifying pairs of attributes strongly correlated, aiding in feature selection or understanding potential multicollinearity issues in predictive modeling.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Correlation Intensity:** Colors in the heatmap indicate the strength of correlations, where darker shades represent stronger correlations (positive or negative) between attributes.
# * **Pattern Recognition:** Clusters of dark or light-colored squares reveal groups of attributes that are strongly or weakly correlated, respectively.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
numerical_data = merged_data.select_dtypes(include=['float64', 'int64'])

# Creating a pair plot
sns.pairplot(numerical_data)
plt.suptitle('Pair Plot of Numerical Columns', y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * **Comprehensive Relationship Display:** Pair plots offer a grid of scatterplots showcasing correlations among numerical columns, aiding in quick identification of potential correlations or patterns.
# * **Visualization of Multiple Features:** This plot allows simultaneous examination of relationships between various numerical attributes, providing a holistic view of their interactions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Correlation Identification:** The pair plot helps identify potential linear or non-linear relationships between different numerical attributes. Clusters or trends in scatterplots indicate possible correlations or lack thereof.
# * **Distribution Comparison:** The diagonal of the pair plot shows the distribution of individual numerical attributes, helping in assessing their spread and central tendency.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# **User Engagement:** Enhance app features based on positive reviews and ratings, focusing on user-favored aspects. Address concerns from negative reviews to boost overall satisfaction and engagement.
#
# **App Visibility:** Target app development efforts towards categories with high ratings, reviews, and downloads. Tailor marketing strategies to showcase unique app features and attract more downloads.
#
# **App Quality:** Prioritize bug fixes and updates based on user feedback to improve stability. Optimize app performance and size to enhance user experience without compromising functionality.
#
# **Monetization:** Explore opportunities for revenue generation by understanding user preferences for paid apps within specific categories. Consider offering premium features in high-demand categories.
#
# **User Retention:** Analyze user behavior patterns to identify factors contributing to long-term user retention. Implement strategies to encourage continued app usage and satisfaction.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This project, founded on comprehensive app data analysis, drives actionable insights to elevate app performance and meet business objectives effectively. By prioritizing user feedback, targeting high-performing categories, and ensuring quality and stability through bug fixes and optimizations, it fosters a user-centric approach. Identifying monetization avenues and implementing retention strategies based on user behavior propels sustained engagement and loyalty. Through data-driven decisions and user-focused enhancements, this project sets the stage for continuous app success and business goal achievement in a dynamic app market.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
